# %% [markdown]
# <a href="https://colab.research.google.com/github/codingwithrahat/LLM-Course/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(5)
# Out:
# 5
